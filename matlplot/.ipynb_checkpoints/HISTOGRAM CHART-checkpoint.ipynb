# %% [markdown]
# # HISTOGRAM CHART

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10,60,50)
print(x)
# Out:
# [13 55 15 35 20 37 56 49 45 33 14 50 56 43 43 57 17 15 32 21 45 40 37 51
#  55 31 44 12 52 34 44 22 59 53 36 35 12 13 18 33 51 49 33 27 55 17 16 38
#  33 15]

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]
plt.hist(no)

plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]


plt.hist(no, color ="r", edgecolor = "b")

plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no, color ="r", edgecolor = "b", bins=l) # bins

plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no,"auto",(0,200) ,color ="r", edgecolor = "b",) # "auto",(0,100) it is range parameter it always be 3rd parameter

plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]


plt.hist(no, color ="r", edgecolor = "b", cumulative=+1) #cumulative

plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]


plt.hist(no, color ="r", edgecolor = "b", cumulative=-1) #cumulative

plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]


plt.hist(no, color ="r", edgecolor = "b", bottom=20) #bottom

plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]


plt.hist(no, color ="r", edgecolor = "b", align="left") #align

plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no,bins= l,color ="r", edgecolor = "b",histtype="step") #histtype
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no,bins= l,color ="b", edgecolor = "r",histtype="stepfilled") #histtype
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no,bins= l,color ="r", edgecolor = "b",histtype="barstacked") #histtype
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no,bins= l,color ="r", edgecolor = "b",histtype="bar") #histtype
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no,bins= l,color ="r", edgecolor = "b",orientation="horizontal") # oriebtation
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no,bins= l,color ="r", edgecolor = "b",orientation="vertical") # oriebtation
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no,bins= l,color ="r", edgecolor = "b",) # 
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no,bins= l,color ="r", edgecolor = "b", log=True) # log
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")
plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no, bins= l, color ="r", edgecolor = "b", label="Python") #
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")

plt.axvline(35, color = "g", label="line") # axvline

plt.legend()

plt.show()

# %%
no = [13,55,15,35,20,37,56,49,45,33,14,50,56,43,43,57,17,15,32,21,45,40,37,51,55,31,44,12,52,
      34,44,22,59,53,36,35,12,13,18,33,51,49,33,27,55,17,16,38,33,15]

l = [10,20,30,40,50,60]
plt.hist(no, bins= l, color ="r", edgecolor = "b", label="Python") #
plt.title("Histrogram")
plt.xlabel("phyton data")
plt.ylabel("no")

plt.axvline(35, color = "g", label="line") # axvline

plt.legend()

plt.grid(label="grid") #grid

plt.show()
